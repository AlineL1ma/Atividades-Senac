# %%
dia = "quinta-feira"

# %%
dia = 32.5

# %%
print(dia)
# Out:
# 32.5

# %%
dia = 19

# %%
print((18 // 4), (18 % 4), (18/4))
# Out:
# 4 2 4.5

# %%
n = input("Por favor, entre com sa idade:") # usuário entra com 18
print (type(n))
# Out:
# <class 'str'>

# %%
x = 16 - 2 * 5 // 3 + 1
y = 2 ** 2 ** 3 * 3
print(x, y)
# Out:
# 14 768

# %%
x = 12
x-= 1
print(x)
# Out:
# 11
